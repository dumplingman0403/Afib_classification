# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import Eval_model
import pickle
# Out:
# Using TensorFlow backend.

# %%
def cnn_model_2d(x_train, y_train, x_test, y_test, epochs =50):
    nClass = 4
    model = Sequential()
    model.add(Conv2D(32, (3,3), activation = 'relu', input_shape = x_train.shape[1:]))
    model.add(Conv2D(64, (3,3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2,2)))
    model.add(Dropout(0.25))
    model.add(Conv2D(64, (3,3), activation = 'relu'))
    model.add(Conv2D(64, (3,3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2,2)))
    model.add(Dropout(0.25))
    
    model.add(Flatten())
    model.add(Dropout(0.2))
    model.add(Dense(512, activation = 'relu'))
    model.add(Dense(128, activation = 'relu'))
    #model.add(Dropout(0.2))
    model.add(Dense(nClass, activation = 'softmax' ))

    model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', 
                  metrics = ['accuracy'])
    callbacks = [EarlyStopping(monitor='val_loss', patience = 20), 
                 ModelCheckpoint(filepath='best_model.h5', monitor='val_loss', save_best_only=True)
                 ]
    history = model.fit(x_train, y_train, batch_size = 32, epochs = epochs,
                        callbacks = callbacks, validation_data = (x_test, y_test) )
    
    #model.load_weights('best_model.h5')
    model.summary()
    return model, history

# %%
def InputPreprocess(x_train, y_train, x_test, y_test, IMG_SIZE = 100):
    
    #reshape
    x_train /= 255
    x_test  /= 255
    
    x_train = np.reshape(x_train, (-1, IMG_SIZE, IMG_SIZE, 1))
    x_test = np.reshape(x_test, (-1, IMG_SIZE, IMG_SIZE, 1))

    
    y_true = y_test
    #to categorical label

    y_train = to_categorical(y_train, num_classes = 4, dtype = 'int8')
    y_test = to_categorical(y_test, num_classes = 4, dtype = 'int8' )
    
    return x_train, y_train, x_test, y_test, y_true

# %%
train = pickle.load(open('train_temp_input.pk1', 'rb'))
test = pickle.load(open('test_temp_input.pk1', 'rb'))
x_train = []
y_train = []

for lb, sg in train:
    x_train.append(sg)
    y_train.append(lb)

x_train = np.array(x_train).astype('float32')
y_train = np.array(y_train).astype('int8')

x_test = []
y_test = []
for lb, sg in test:
    x_test.append(sg)
    y_test.append(lb)

x_test = np.array(x_test).astype('float32')
y_test = np.array(y_test).astype('int8')

# %%
x_train, y_train, x_test, y_test, y_true = InputPreprocess(x_train, y_train, x_test, y_test)

# %%
model, history = cnn_model_2d(x_train, y_train, x_test, y_test, 50)
# Out:
# Train on 8528 samples, validate on 300 samples
# Epoch 1/50
# 8528/8528 [==============================] - 32s 4ms/sample - loss: 0.8990 - accuracy: 0.6193 - val_loss: 1.0020 - val_accuracy: 0.5533
# Epoch 2/50
# 8528/8528 [==============================] - 21s 3ms/sample - loss: 0.7707 - accuracy: 0.6717 - val_loss: 0.8036 - val_accuracy: 0.6700
# Epoch 3/50
# 8528/8528 [==============================] - 21s 3ms/sample - loss: 0.7036 - accuracy: 0.6945 - val_loss: 0.6820 - val_accuracy: 0.7433
# Epoch 4/50
# 8528/8528 [==============================] - 21s 2ms/sample - loss: 0.6586 - accuracy: 0.7153 - val_loss: 0.6533 - val_accuracy: 0.7167
# Epoch 5/50
# 8528/8528 [==============================] - 22s 3ms/sample - loss: 0.6028 - accuracy: 0.7424 - val_loss: 0.5682 - val_accuracy: 0.7800
# Epoch 6/50
# 8528/8528 [==============================] - 22s 3ms/sample - loss: 0.5447 - accuracy: 0.7603 - val_loss: 0.4636 - val_accuracy: 0.8533
# Epoch 7/50
# 8528/8528 [==============================] - 20s 2ms/sample - loss: 0.4628 - accuracy: 0.8050 - val_loss: 0.4699 - val_accuracy: 0.8433
# Epoch 8/50
# 8528/8528 [==============================] - 22s 3ms/sample - loss: 0.3900 - accuracy: 0.8394 - val_loss: 0.4157 - val_accuracy: 0.8800
# Epoch 9/50
# 8528/8528 [==============================] - 21s 3ms/sample - loss: 0.3133 - accuracy: 0.8738 - val_loss: 0.4134 - val_accuracy: 0.9067
# Epoch 10/50
# 8528/8528 [==============================] - 20s 2ms/sample - loss: 0.2629 - accuracy: 0.8931 - val_loss: 0.4844 - val_accuracy: 0.9300
# Epoch 11/50
# 8528/8528 [==============================] - 20s 2ms/sample - loss: 0.2033 - accuracy: 0.9189 - val_loss: 0.4543 - val_accuracy: 0.9433
# Epoch 12/50
# 8528/8528 [==============================] - 20s 2ms/sample - loss: 0.1792 - accuracy: 0.9328 - val_loss: 0.4767 - val_accuracy: 0.9433
# Epoch 13/50
# 8528/8528 [==============================] - 20s 2ms/sample - loss: 0.1621 - accuracy: 0.9377 - val_loss: 0.5709 - val_accuracy: 0.9333
# Epoch 14/50
# 8528/8528 [==============================] - 22s 3ms/sample - loss: 0.1369 - accuracy: 0.9488 - val_loss: 0.3732 - val_accuracy: 0.9533
# Epoch 15/50
# 8528/8528 [==============================] - 20s 2ms/sample - loss: 0.0995 - accuracy: 0.9628 - val_loss: 0.4552 - val_accuracy: 0.9500
# Epoch 16/50
# 8528/8528 [==============================] - 20s 2ms/sample - loss: 0.0935 - accuracy: 0.9660 - val_loss: 0.5530 - val_accuracy: 0.9433
# Epoch 17/50
# 8528/8528 [==============================] - 20s 2ms/sample - loss: 0.0865 - accuracy: 0.9699 - val_loss: 0.5028 - val_accuracy: 0.9500
# Epoch 18/50
# 8528/8528 [==============================] - 20s 2ms/sample - loss: 0.0678 - accuracy: 0.9757 - val_loss: 0.7018 - val_accuracy: 0.9500
# Epoch 19/50
# 8528/8528 [==============================] - 20s 2ms/sample - loss: 0.0726 - accuracy: 0.9760 - val_loss: 0.5973 - val_accuracy: 0.9467
# Epoch 20/50
# 8528/8528 [==============================] - 20s 2ms/sample - loss: 0.0524 - accuracy: 0.9832 - val_loss: 0.7013 - val_accuracy: 0.9467
# Epoch 21/50
# 8528/8528 [==============================] - 20s 2ms/sample - loss: 0.0591 - accuracy: 0.9816 - val_loss: 0.5853 - val_accuracy: 0.9533
# Epoch 22/50
# 8528/8528 [==============================] - 20s 2ms/sample - loss: 0.0455 - accuracy: 0.9848 - val_loss: 0.6197 - val_accuracy: 0.9533
# Epoch 23/50
# 8528/8528 [==============================] - 20s 2ms/sample - loss: 0.0417 - accuracy: 0.9859 - val_loss: 0.5412 - val_accuracy: 0.9533
# Epoch 24/50
# 8528/8528 [==============================] - 20s 2ms/sample - loss: 0.0606 - accuracy: 0.9811 - val_loss: 0.5372 - val_accuracy: 0.9533
# Epoch 25/50
# 8528/8528 [==============================] - 20s 2ms/sample - loss: 0.0391 - accuracy: 0.9870 - val_loss: 0.8037 - val_accuracy: 0.9500
# Epoch 26/50
# 8528/8528 [==============================] - 20s 2ms/sample - loss: 0.0421 - accuracy: 0.9857 - val_loss: 0.6282 - val_accuracy: 0.9567
# Epoch 27/50
# 8528/8528 [==============================] - 20s 2ms/sample - loss: 0.0380 - accuracy: 0.9880 - val_loss: 0.6415 - val_accuracy: 0.9533
# Epoch 28/50
# 8528/8528 [==============================] - 20s 2ms/sample - loss: 0.0317 - accuracy: 0.9904 - val_loss: 0.6416 - val_accuracy: 0.9467
# Epoch 29/50
# 8528/8528 [==============================] - 20s 2ms/sample - loss: 0.0275 - accuracy: 0.9907 - val_loss: 0.9927 - val_accuracy: 0.9533
# Epoch 30/50
# 8528/8528 [==============================] - 20s 2ms/sample - loss: 0.0447 - accuracy: 0.9863 - val_loss: 0.8154 - val_accuracy: 0.9500
# Epoch 31/50
# 8528/8528 [==============================] - 20s 2ms/sample - loss: 0.0349 - accuracy: 0.9889 - val_loss: 0.9636 - val_accuracy: 0.9533
# Epoch 32/50
# 8528/8528 [==============================] - 20s 2ms/sample - loss: 0.0281 - accuracy: 0.9911 - val_loss: 0.7146 - val_accuracy: 0.9533
# Epoch 33/50
# 8528/8528 [==============================] - 20s 2ms/sample - loss: 0.0392 - accuracy: 0.9875 - val_loss: 0.9434 - val_accuracy: 0.9533
# Epoch 34/50
# 8528/8528 [==============================] - 20s 2ms/sample - loss: 0.0207 - accuracy: 0.9933 - val_loss: 0.7948 - val_accuracy: 0.9533
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 98, 98, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 96, 96, 64)        18496
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 48, 48, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 48, 48, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 46, 46, 64)        36928
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 44, 44, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 22, 22, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 22, 22, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 30976)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               15860224
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 516
# =================================================================
# Total params: 16,019,076
# Trainable params: 16,019,076
# Non-trainable params: 0
# _________________________________________________________________

# %%
Eval_model.get_summary(x_test, y_true, model)
# Out:
# Accuracy = 95.33%
# F1 score = 93.52
# Sensitivity: Normal = 0.967, AFib = 0.940, Others = 0.914, Noise = 1.000
# Specificity: Normal = 0.987, AFib = 0.996, Others = 0.996, Noise = 0.963
# Positive predictive value: Normal = 0.986, AFib = 0.979, Others = 0.985, Noise = 0.750
# Negative predictive value: Normal = 0.967, AFib = 0.988, Others = 0.974, Noise = 1.000
# Confusion matrix, without normalization
# Normalized confusion matrix

# %%
Eval_model.Plot_Acc_and_Loss(history, x_test, y_test, model)
# Out:
# Accuracy: 95.33%
